# %% [markdown]
# <a href="https://colab.research.google.com/github/Aguilar-Romero/Metodos-numericos-1/blob/main/RaizyCuadrados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
x=np.sqrt(3)
print(x)
print(x**2)
# Out:
# 1.7320508075688772
# 2.9999999999999996
